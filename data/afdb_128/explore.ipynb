# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("filtered_metadata.csv")
afdb_df = df[df.pdb_name.str.contains("model_v4")]
pdb_df = df[~df.pdb_name.str.contains("model_v4")]
# Out:
# /scratch/alexjli/ipykernel_1541384/93963485.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("filtered_metadata.csv")

# %%
cluster_groupby = pdb_df.groupby('cluster').count()
cluster_groupby[cluster_groupby['pdb_name'] > 1]
# sns.histplot()
# Out:
#          Unnamed: 0  pdb_name  processed_path  raw_path  oligomeric_count  \
# cluster
# 1                47        47              47        47                47
# 2                23        23              23        23                23
# 69                2         2               2         2                 2
# 90              250       250             250       250               250
# 95               11        11              11        11                11
# ...             ...       ...             ...       ...               ...
# 124067            2         2               2         2                 2
# 124171            2         2               2         2                 2
# 124216            2         2               2         2                 2
# 125940            2         2               2         2                 2
# 126775            2         2               2         2                 2
#
#          oligomeric_detail  resolution  structure_method  num_chains  \
# cluster
# 1                       47          47                47          47
# 2                       23          23                23          23
# 69                       2           2                 2           2
# 90                     250         250               250         250
# 95                      11          11                11          11
# ...                    ...         ...               ...         ...
# 124067                   2           2                 2           2
# 124171                   2           2                 2           2
# 124216                   2           2                 2           2
# 125940                   2           2                 2           2
# 126775                   2           2                 2           2
#
#          quaternary_category  seq_len  modeled_seq_len  coil_percent  \
# cluster
# 1                         47       47               47            47
# 2                         23       23               23            23
# 69                         2        2                2             2
# 90                       250      250              250           250
# 95                        11       11               11            11
# ...                      ...      ...              ...           ...
# 124067                     2        2                2             2
# 124171                     2        2                2             2
# 124216                     2        2                2             2
# 125940                     2        2                2             2
# 126775                     2        2                2             2
#
#          helix_percent  strand_percent  radius_gyration
# cluster
# 1                   47              47               47
# 2                   23              23               23
# 69                   2               2                2
# 90                 250             250              250
# 95                  11              11               11
# ...                ...             ...              ...
# 124067               2               2                2
# 124171               2               2                2
# 124216               2               2                2
# 125940               2               2                2
# 126775               2               2                2
#
# [493 rows x 16 columns]

# %%
print(len(pdb_df['cluster'].unique()), len(pdb_df), len(pdb_df)-len(pdb_df['cluster'].unique()))
print(len(afdb_df['cluster'].unique()), len(afdb_df))
print(len(df['cluster'].unique()), len(df), len(df) - len(df['cluster'].unique()))
# Out:
# 2149 4887 2738
# 30954 30954
# 33103 35841 2738

# %%
0.25 * pdb_df.groupby('cluster')['modeled_seq_len'].mean().mean() + 0.75 * afdb_df['modeled_seq_len'].mean()
# Out:
# 96.11925310150652
