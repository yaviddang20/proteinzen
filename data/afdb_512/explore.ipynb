# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("filtered_metadata.csv")
df = df[(df['modeled_seq_len'] > 31) & (df['modeled_seq_len'] <= 512)]
df = df[(df['coil_percent'] < 0.5)]
afdb_df = df[df.pdb_name.str.contains("model_v4")]
pdb_df = df[~df.pdb_name.str.contains("model_v4")]
# Out:
# /tmp/ipykernel_864450/93963485.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("filtered_metadata.csv")

# %%
cluster_groupby = pdb_df.groupby('cluster').count()
cluster_groupby[cluster_groupby['pdb_name'] > 1]
# sns.histplot()
# Out:
#          Unnamed: 0  pdb_name  processed_path  raw_path  oligomeric_count  \
# cluster
# 0                21        21              21        21                21
# 1               937       937             937       937               937
# 2                23        23              23        23                23
# 3               612       612             612       612               612
# 12              536       536             536       536               536
# ...             ...       ...             ...       ...               ...
# 127157            2         2               2         2                 2
# 127265            2         2               2         2                 2
# 127318            2         2               2         2                 2
# 127504            2         2               2         2                 2
# 127567            2         2               2         2                 2
#
#          oligomeric_detail  resolution  structure_method  num_chains  \
# cluster
# 0                       21          21                21          21
# 1                      937         937               937         937
# 2                       23          23                23          23
# 3                      612         612               612         612
# 12                     536         536               536         536
# ...                    ...         ...               ...         ...
# 127157                   2           2                 2           2
# 127265                   2           2                 2           2
# 127318                   2           2                 2           2
# 127504                   2           2                 2           2
# 127567                   2           2                 2           2
#
#          quaternary_category  seq_len  modeled_seq_len  coil_percent  \
# cluster
# 0                         21       21               21            21
# 1                        937      937              937           937
# 2                         23       23               23            23
# 3                        612      612              612           612
# 12                       536      536              536           536
# ...                      ...      ...              ...           ...
# 127157                     2        2                2             2
# 127265                     2        2                2             2
# 127318                     2        2                2             2
# 127504                     2        2                2             2
# 127567                     2        2                2             2
#
#          helix_percent  strand_percent  radius_gyration
# cluster
# 0                   21              21               21
# 1                  937             937              937
# 2                   23              23               23
# 3                  612             612              612
# 12                 536             536              536
# ...                ...             ...              ...
# 127157               2               2                2
# 127265               2               2                2
# 127318               2               2                2
# 127504               2               2                2
# 127567               2               2                2
#
# [2788 rows x 16 columns]

# %%
print(len(pdb_df['cluster'].unique()), len(pdb_df), len(pdb_df)-len(pdb_df['cluster'].unique()))
print(len(afdb_df['cluster'].unique()), len(afdb_df))
print(len(df['cluster'].unique()), len(df), len(df) - len(df['cluster'].unique()))
# Out:
# 8954 27094 18140
# 81056 81056
# 90010 108150 18140
